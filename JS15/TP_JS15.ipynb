# %% [markdown]
# # Tugas TP_JS15
# Setelah berhasil melakukan deployment pada studi kasus latihan ("Day vs Night"), tugas Anda selanjutnya adalah menerapkan pipeline deployment yang sama untuk model Project anda masing-masing.
#
# ## Repo Github for Batik Classifier
# - [Github Batik Classifier](https://github.com/TMTMPST/Model-PCVK/tree/main/Diff/VGG16/70%25)
# ## Repo HuggingFace Space for Batik Classifier
# - [HuggingFace Space Link](https://huggingface.co/spaces/RimsJ/batik-classifier)
# - [HuggingFace Model Link](https://huggingface.co/RimsJ/Batik-Classifier/tree/main)
#
# ### Dikarenakan model lebih dari 1 GB dan batas penyimpanan di HuggingFace Space hanya 1 GB maks, maka model disimpan di HuggingFace Model Repository terpisah.
